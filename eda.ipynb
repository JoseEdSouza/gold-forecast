# %%
from pathlib import Path

import pandas as pd

# %%
DATA_PATH = Path("./data")
OUTPUT_PATH = Path("./out")
GOLD_DATA_PATH = OUTPUT_PATH / "final_gold_data_embeddings.parquet"

# %%
gold = pd.read_parquet(GOLD_DATA_PATH)
gold.head()
# Out:
#    timestamp   open   high    low  close  volume currency   unit  \
# 0 2000-08-30  273.9  273.9  273.9  273.9       0      usd  ounce
# 1 2000-08-31  274.8  278.3  274.8  278.3       0      usd  ounce
# 2 2000-09-01  277.0  277.0  277.0  277.0       0      usd  ounce
# 3 2000-09-05  275.8  275.8  275.8  275.8       2      usd  ounce
# 4 2000-09-06  274.2  274.2  274.2  274.2       0      usd  ounce
#
#                                            headlines  \
# 0  Recalls Fuel Disclosure Debate / Deutsche Tele...
# 1  Credit Suisse's Wheat Faces Deal / Regulators ...
# 2  Nordstrom's Chief Resigns / Judge Dismisses Ca...
# 3  Market Pace Slows After 10-Year Run / Clickman...
# 4  France Telecom Profit Increases / Locale-Based...
#
#                                         emb_nomic_1d  \
# 0  [0.016506249085068703, 0.05451096221804619, -0...
# 1  [0.0030195650178939104, 0.0543488971889019, -0...
# 2  [0.00742419995367527, 0.015169485472142696, -0...
# ...

# %%
gold["headlines"].str.split("/").apply(len).value_counts().sort_index()
# Out:
# headlines
# 1      85
# 2     123
# 3     160
# 4     211
# 5     222
# 6     260
# 7     272
# 8     283
# 9     283
# 10    276
# 11    311
# 12    292
# 13    302
# 14    329
# 15    348
# 16    294
# 17    282
# 18    291
# 19    246
# 20    258
# 21    180
# 22    186
# 23    118
# 24    132
# 25    111
# 26     99
# 27     79
# 28     49
# 29     30
# 30     25
# 31     20
# 32      9
# 33      5
# 34      2
# 35      4
# Name: count, dtype: int64

# %%
gold
# Out:
#       timestamp    open    high     low   close  volume currency   unit  \
# 0    2000-08-30   273.9   273.9   273.9   273.9       0      usd  ounce
# 1    2000-08-31   274.8   278.3   274.8   278.3       0      usd  ounce
# 2    2000-09-01   277.0   277.0   277.0   277.0       0      usd  ounce
# 3    2000-09-05   275.8   275.8   275.8   275.8       2      usd  ounce
# 4    2000-09-06   274.2   274.2   274.2   274.2       0      usd  ounce
# ...         ...     ...     ...     ...     ...     ...      ...    ...
# 6172 2025-04-08  2994.0  3014.5  2968.4  2968.4    3213      usd  ounce
# 6173 2025-04-09  2965.8  3090.4  2965.8  3056.5    2175      usd  ounce
# 6174 2025-04-10  3073.9  3167.0  3072.1  3155.2    3456      usd  ounce
# 6175 2025-04-11  3182.1  3235.0  3182.1  3222.2     862      usd  ounce
# 6176 2025-04-14  3215.5  3228.8  3194.5  3204.8     263      usd  ounce
#
#                                               headlines  \
# ...

# %%
gold.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6177 entries, 0 to 6176
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            6177 non-null   datetime64[us]
#  1   open                 6177 non-null   float64
#  2   high                 6177 non-null   float64
#  3   low                  6177 non-null   float64
#  4   close                6177 non-null   float64
#  5   volume               6177 non-null   int64
#  6   currency             6177 non-null   str
#  7   unit                 6177 non-null   str
#  8   headlines            6177 non-null   str
#  9   emb_nomic_1d         6177 non-null   object
#  10  emb_nomic_7d         6177 non-null   object
#  11  emb_nomic_dev_1d_7d  6177 non-null   object
# dtypes: datetime64[us](1), float64(4), int64(1), object(3), str(3)
# memory usage: 4.5+ MB
